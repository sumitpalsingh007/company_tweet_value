# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
comapny_tweet = pd.read_csv('/Users/sps/code/company_tweet_value/Company_Tweet.csv')
tweet = pd.read_csv('/Users/sps/code/company_tweet_value/Tweet.csv')
company = pd.read_csv('/Users/sps/code/company_tweet_value/Company.csv')
company_value = pd.read_csv('/Users/sps/code/company_tweet_value/CompanyValues.csv')

# %%
comapny_tweet.head()
# Out:
#              tweet_id ticker_symbol
# 0  550803612197457920          AAPL
# 1  550803610825928706          AAPL
# 2  550803225113157632          AAPL
# 3  550802957370159104          AAPL
# 4  550802855129382912          AAPL

# %%
company_value.head()
# Out:
#                close_value     volume  open_value  high_value  low_value
# ticker_symbol
# AAPL                327.20  462442329      324.74    327.8500    323.350
# AMZN               2497.94   42394400     2500.00   2525.4500   2467.270
# GOOG               1526.69   11153500     1525.07   1532.1063   1521.400
# GOOGL              1524.87   14803480     1527.20   1530.7400   1520.976
# MSFT                188.70  269764900      190.65    190.7000    186.470

# %%
company_value = company_value.groupby('ticker_symbol')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-a32d561e8d5c> in <module>
# ----> 1 company_value = company_value.groupby('ticker_symbol')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
company_value=company_value.max('day_date')
company_value.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'day_date'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-52198ab73d03> in <module>
# ----> 1 company_value=company_value.max('day_date')
#       2 company_value.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
# ...

# %%
tweet.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1

# %%
company.head()
# Out:
#   ticker_symbol company_name
# 0          AAPL        apple
# 1          GOOG   Google Inc
# 2         GOOGL   Google Inc
# 3          AMZN   Amazon.com
# 4          TSLA    Tesla Inc

# %%
joined_df = tweet.merge(right=comapny_tweet, on="tweet_id", how="left")
joined_df.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num ticker_symbol
# 0            0         1          AAPL
# 1            0         0          AAPL
# 2            0         0          AMZN
# 3            0         1          TSLA
# 4            0         1          AAPL

# %%
joined_df = joined_df.merge(right=company, on="ticker_symbol", how="left")
joined_df.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num ticker_symbol company_name
# 0            0         1          AAPL        apple
# 1            0         0          AAPL        apple
# 2            0         0          AMZN   Amazon.com
# ...

# %%
joined_df = joined_df.merge(right=company_value, on="ticker_symbol", how="left")
joined_df.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num ticker_symbol company_name  close_value       volume  \
# 0            0         1          AAPL        apple       327.20  462442329.0
# 1            0         0          AAPL        apple       327.20  462442329.0
# ...

# %%
joined_df = joined_df.drop(labels=(['open_value','high_value','low_value','tweet_id']), axis=1)

# %%
joined_df.head()
# Out:
#             writer   post_date  \
# 0  VisualStockRSRC  1420070457
# 1      KeralaGuy77  1420070496
# 2      DozenStocks  1420070510
# 3     ShowDreamCar  1420070807
# 4     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num ticker_symbol company_name  close_value       volume
# 0            0         1          AAPL        apple       327.20  462442329.0
# 1            0         0          AAPL        apple       327.20  462442329.0
# 2            0         0          AMZN   Amazon.com      2497.94   42394400.0
# ...

# %%
import matplotlib as plt;
import seaborn as sns;
# %matplotlib inline

# %%
tweet_counts = joined_df.groupby(by='ticker_symbol').sum('like_num')
#['comment_num','retweet_num','close_value','ticker_symbol']

# %%
tweet_counts.head()
# Out:
#                       post_date  comment_num  retweet_num  like_num  \
# ticker_symbol
# AAPL           2120001790926254       222048       722396   1378670
# AMZN           1079934701070144       152200       419783    984166
# GOOG            580910276881009        30704       147143    235928
# GOOGL           490172505957209        58619       191550    406917
# MSFT            562022854165740        41533       193364    347520
#
#                 close_value        volume
# ticker_symbol
# AAPL           4.662643e+08  6.589863e+14
# AMZN           1.795307e+09  3.046949e+13
# GOOG           5.993312e+08  4.378518e+12
# GOOGL          4.995001e+08  4.849161e+12
# MSFT           7.089667e+07  1.013536e+14

# %%
tweet_counts = tweet_counts.drop(labels = (['post_date','close_value','close_value','volume']), axis =1)

# %%
tweet_counts.head()
# Out:
#                comment_num  retweet_num  like_num
# ticker_symbol
# AAPL                222048       722396   1378670
# AMZN                152200       419783    984166
# GOOG                 30704       147143    235928
# GOOGL                58619       191550    406917
# MSFT                 41533       193364    347520

# %%
df1 = joined_df[['ticker_symbol','close_value']]
df1.head()
# Out:
#   ticker_symbol  close_value
# 0          AAPL       327.20
# 1          AAPL       327.20
# 2          AMZN      2497.94
# 3          TSLA          NaN
# 4          AAPL       327.20

# %%
tweet_counts.merge(right=df1, on='ticker_symbol', how ='left')
# Out:
#         ticker_symbol  comment_num  retweet_num  like_num  close_value
# 0                AAPL       222048       722396   1378670        327.2
# 1                AAPL       222048       722396   1378670        327.2
# 2                AAPL       222048       722396   1378670        327.2
# 3                AAPL       222048       722396   1378670        327.2
# 4                AAPL       222048       722396   1378670        327.2
# ...               ...          ...          ...       ...          ...
# 4336440          TSLA       762813      1078386   5769051          NaN
# 4336441          TSLA       762813      1078386   5769051          NaN
# 4336442          TSLA       762813      1078386   5769051          NaN
# 4336443          TSLA       762813      1078386   5769051          NaN
# 4336444          TSLA       762813      1078386   5769051          NaN
#
# [4336445 rows x 5 columns]
